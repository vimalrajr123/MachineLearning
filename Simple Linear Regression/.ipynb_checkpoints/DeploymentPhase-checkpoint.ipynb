# %%
import pickle

# %%
load_model = pickle.load(open("finalized_model_linear.sav",'rb'))   #load() takes the file in and gives back the original python object
result = load_model.predict([[15]])
# Out:
# /Users/spark/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
result
# Out:
# array([[167181.3106341]])
